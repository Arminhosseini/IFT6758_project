# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# %% [markdown]
# # 0. Read dataset
#
# In this section, I will read from the raw data (`json` file).

# %%
PATH_TIDY_DATA_CSV = r"Dataset/tidyData.csv"

# %%
df = pd.read_csv(PATH_TIDY_DATA_CSV)
df = df.reset_index()
print(f"Shape of df: {df.shape}")
df.head(10)
# Out:
# Shape of df: (385076, 20)
#    index      gamePk            homeTeam  period periodType periodTime  \
# 0      0  2018021200  Colorado Avalanche       1    REGULAR      00:35
# 1      1  2018021200  Colorado Avalanche       1    REGULAR      01:44
# 2      2  2018021200  Colorado Avalanche       1    REGULAR      02:42
# 3      3  2018021200  Colorado Avalanche       1    REGULAR      05:19
# 4      4  2018021200  Colorado Avalanche       1    REGULAR      05:53
# 5      5  2018021200  Colorado Avalanche       1    REGULAR      07:02
# 6      6  2018021200  Colorado Avalanche       1    REGULAR      07:19
# 7      7  2018021200  Colorado Avalanche       1    REGULAR      07:48
# 8      8  2018021200  Colorado Avalanche       1    REGULAR      08:11
# 9      9  2018021200  Colorado Avalanche       1    REGULAR      08:23
#
#   periodTimeRemaining              dateTime  teamId            teamName  \
# 0               19:25  2019-03-30T01:09:28Z      21  Colorado Avalanche
# 1               18:16  2019-03-30T01:11:28Z      21  Colorado Avalanche
# 2               17:18  2019-03-30T01:13:23Z      21  Colorado Avalanche
# 3               14:41  2019-03-30T01:16:58Z      53     Arizona Coyotes
# 4               14:07  2019-03-30T01:19:11Z      53     Arizona Coyotes
# 5               12:58  2019-03-30T01:20:48Z      21  Colorado Avalanche
# 6               12:41  2019-03-30T01:21:05Z      21  Colorado Avalanche
# 7               12:12  2019-03-30T01:21:34Z      21  Colorado Avalanche
# 8               11:49  2019-03-30T01:21:56Z      53     Arizona Coyotes
# 9               11:37  2019-03-30T01:24:22Z      53     Arizona Coyotes
#
#   attackingSide teamTriCode eventType  x-coordinate  y-coordinate  \
# 0          left         COL      Shot         -75.0          -5.0
# 1          left         COL      Shot         -37.0          33.0
# 2          left         COL      Shot         -80.0          -6.0
# 3         right         ARI      Shot          62.0         -23.0
# 4         right         ARI      Shot          -7.0          36.0
# 5          left         COL      Shot         -70.0         -21.0
# 6          left         COL      Shot         -67.0         -38.0
# 7          left         COL      Shot         -79.0         -20.0
# 8         right         ARI      Shot          51.0          23.0
# 9         right         ARI      Shot          37.0           1.0
#
#          goalieName        shooterName    shotType isEmptyNet strength
# 0     Darcy Kuemper  Gabriel Landeskog    Backhand        NaN    False
# 1     Darcy Kuemper       Tyson Barrie  Wrist Shot        NaN    False
# 2     Darcy Kuemper       Colin Wilson  Wrist Shot        NaN    False
# 3  Philipp Grubauer      Richard Panik  Wrist Shot        NaN    False
# 4  Philipp Grubauer      Lawson Crouse  Wrist Shot        NaN    False
# 5     Darcy Kuemper   Sven Andrighetto  Wrist Shot        NaN    False
# 6     Darcy Kuemper    Derick Brassard  Wrist Shot        NaN    False
# 7     Darcy Kuemper         Tyson Jost  Wrist Shot        NaN    False
# 8  Philipp Grubauer    Jordan Oesterle  Wrist Shot        NaN    False
# 9  Philipp Grubauer       Nick Cousins  Wrist Shot        NaN    False

# %% [markdown]
# # 1. Include simple features

# %%
def time_string_to_seconds(time_str):
    """
    This function convert from mm:ss to the total number of seconds. For example: "03:45" -> 225
    """
    try:
        minutes, seconds = map(int, time_str.split(':'))
    except:
        print(f"Error in time string. Current time string: {time_str}")
    total_seconds = minutes * 60 + seconds
    return total_seconds

# %%
list_game_seconds = []
list_game_period = []
list_coordinates_x = []
list_coordinates_y = []
list_shot_distance = []
list_shot_angle = []
list_shot_type = []

for idx_event, shot_event in df.iterrows():
    game_seconds = time_string_to_seconds(shot_event['periodTime']) + (int(shot_event['period']) - 1) * 20 * 60 
    game_period = shot_event['period']
    coor_x = shot_event['x-coordinate']
    coor_y = shot_event['y-coordinate']

# %%
def Determine_Shooting_Net(home_team, shoter_tem, period):
    
    is_home_shot = True 
    if home_team.lower() != shoter_tem.lower():
        is_home_shot = False    # Away shot

    if is_home_shot:

    else:
        pass
